# %%
# Get the password
import getpass
password = getpass.getpass("Enter your password: ")
# Out:
# Enter your password:  ········

# %%
# Imported libraries.
import requests
import importlib
from bs4 import BeautifulSoup
import pandas as pd
import snowflake.connector
import sqlalchemy as db
import numpy as np
import import_ipynb
import re
from datetime import datetime, timedelta



# Import my files.
import snowflake_functions as sf  # Import the notebook as a module.
import transform_data as td 
import extract_data as ed 
from skills_array import get_skills_array
skills_array = get_skills_array() # get full list of skills.

# %%
# upload latest function
importlib.reload(sf)
importlib.reload(ed)
importlib.reload(td)

# initialise URL list
full_URLs = []

# intialise tables that will later be loaded to snowflake
job_table = pd.DataFrame(columns=['JOB_ID', 'TITLE','COMPANY','LOCATION','EMPLOYMENT_TYPE','SALARY','PAY_PERIOD','POST_DATE'])
job_skills_table = pd.DataFrame(columns=["skill_id", "skill_name"])

# connection snowflake
engine = sf.connect_snowflake(password)
connection = engine.connect()

# get the job_id of the last entry in the jobs table
job_id = sf.last_job_id(connection) + 1

# get job URL links from the first 'max_pages' of data engineer SEEK website pages.
max_pages = 1
full_urls = ed.get_URLs(max_pages)
    
# go through all the URLs and extract relevant data.
for k, url in enumerate(full_urls):   
    
    # Scrape job URL.
    response = requests.get(url) 
    soup = BeautifulSoup(response.content, "html.parser") 
    
    # Enter job ad in to jobs table data frame
    job_props, req_skills = ed.get_job_data(soup, skills_array) # extract the information from job
    parsed_salary = td.parse_salary(job_props[4]) # clean up salary   
    job_table = td.update_job_table(job_props, parsed_salary, job_table, job_id + k) # put into data frame.


    # get that entries id, get skill ids and enter it into job_skills table.
    df_skill_ids = sf.get_skill_ids(req_skills, connection)
    job_skills_table = td.update_job_skills_table(job_props, parsed_salary, job_skills_table, df_skill_ids, job_id + k)
        

# upload tables to snowflake database.
job_table.to_sql('jobs', con=engine, if_exists='append', index=False)
job_skills_table.to_sql('job_skills', con=engine, if_exists='append', index=False)
print(f"\n\n{job_table.shape[0]} SEEK job advertisements added to database.")

# Remove duplicates.
sf.remove_duplicate_entries(connection, password)

# Close connection
connection.close()
# Out:
# Connected to Snowflake!
# Principal Data Engineer | Attribute Group | Sydney NSW | Contract/Temp | None | None | 2025-02-18
# Senior Data Engineer | Talenza | Sydney NSW | Full time | 160000 | annually | 2025-02-25
# Senior Cloud Data Engineer | Australian Taxation Office | Sydney NSW | Full time | 145264 | annually | 2025-02-26
# Lead EIG Engineer (Data Integration/ETL Solutions) | Experis AU | Sydney NSW | Contract/Temp | 80 | annually | None
# Power BI Consultants - All levels - Remote | Agile Analytics | Sydney NSW | Full time | None | None | 2025-02-26
# Lead Data Engineer / Scientist - Up to $220K + Super + Shares | Private Advertiser | Sydney NSW | Full time | 220000 | annually | 2025-02-27
# Machine Learning & Data Engineer | Fundo Loans | Sydney NSW | Full time | 140000 | annually | 2025-02-24
# Senior Data Engineer | Teachers Health Fund | Surry Hills, Sydney NSW | Full time | None | None | 2025-02-24
# Senior Data Engineer & Analytics Specialist | OurPath | Sydney NSW | Full time | 120000 | annually | 2025-02-16
# Principal Data Engineer | Attribute Group | Sydney NSW | Contract/Temp | None | None | 2025-02-18
# Data Engineer | Cuscal Limited (SR) | Sydney NSW | Full time | None | None | 2025-02-22
# Data Engineer | Tranzformd | Sydney NSW | Full time | None | None | 2025-02-25
# Lead Data Engineer | Akkodis | Sydney NSW | Contract/Temp | None | None | 2025-02-27
# Data Engineer | Talent Insights Group Pty Ltd | Sydney NSW | Contract/Temp | None | None | 2025-02-25
# Data Engineer | Mid-Level | Billigence | Sydney NSW | Contract/Temp | None | None | 2025-02-26
# Data Engineer | Bluestone | Sydney NSW | Full time | None | None | 2025-02-22
# Data Engineering Manager | Talenza | Sydney NSW | Full time | 200000 | annually | 2025-02-27
# Junior Data Engineer/Analyst | RASSURE | Chatswood, Sydney NSW | Full time | None | None | 2025-02-27
# Lead Engineer - Big Data | Experis AU | Sydney NSW | Contract/Temp | 95 | annually | None
# Senior Data Engineer (Quantexa) | FinXL IT Professional Services | Sydney NSW | Contract/Temp | None | None | 2025-02-27
# Senior Data Engineer | Talenza | Sydney NSW | Full time | 175000 | annually | 2025-02-25
# Machine Learning & Data Engineer | Fundo Loans | Sydney NSW | Full time | 140000 | annually | 2025-02-24
#
#
# 22 SEEK job advertisements added to database.
#    job_id                                              title  \
# 0       1                   Machine Learning & Data Engineer
# 1       2                                     Data Scientist
# 2       3  Data Engineer - Data Intelligence - Data Platform
# 3       4                     Senior Data Engineer (Contexa)
# 4       5                   Machine Learning & Data Engineer
#
#                           company    location employment_type    salary  \
# 0                     Fundo Loans  Sydney NSW       Full time  140000.0
# 1                       Expert360  Sydney NSW       Full time       NaN
# 2                            None  Sydney NSW       Full time       NaN
# 3  FinXL IT Professional Services  Sydney NSW   Contract/Temp       NaN
# 4                     Fundo Loans  Sydney NSW       Full time  140000.0
#
#   pay_period   post_date
# 0   annually  2025-02-24
# 1       None        None
# 2       None  2025-02-26
# 3       None  2025-02-27
# 4   annually  2025-02-24
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7372\1020000327.py in ?()
#      42 # upload tables to snowflake database and remove duplicates.
#      43 job_table.to_sql('jobs', con=engine, if_exists='append', index=False)
#      44 job_skills_table.to_sql('job_skills', con=engine, if_exists='append', index=False)
#      45 print(f"\n\n{job_table.shape[0]} SEEK job advertisements added to database.")
# ---> 46 sf.remove_duplicates(connection, password)
#      47
#      48 # Close connection
#      49 connection.close()
#
# <string> in ?(connection, password)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6694         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6695         # key that doesn't exist.
#    6696         diff = set(subset) - set(self.columns)
#    6697         if diff:
# -> 6698             raise KeyError(Index(diff))
#    6699
#    6700         if len(subset) == 1 and self.columns.is_unique:
#    6701             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['COMPANY', 'LOCATION', 'SALARY', 'EMPLOYMENT_TYPE', 'POST_DATE',
#        'TITLE', 'PAY_PERIOD'],
#       dtype='object')

# %%
# upload latest function
importlib.reload(sf)
importlib.reload(ed)
importlib.reload(td)

# connection snowflake
engine = sf.connect_snowflake(password)
connection = engine.connect()

sf.remove_duplicate_entries(connection, password)

# Close connection
connection.close()
# Out:
# Connected to Snowflake!
# 0 duplicate job advertisements removed.

# %%
# Close connection
connection.close()
