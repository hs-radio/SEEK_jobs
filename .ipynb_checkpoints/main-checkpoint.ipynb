# %%
# Get the password
import getpass
password = getpass.getpass("Enter your password: ")
# Out:
# Enter your password:  ········

# %%
# Imported libraries.
import requests
import importlib
from bs4 import BeautifulSoup
import pandas as pd
import snowflake.connector
import sqlalchemy as db
import numpy as np
import import_ipynb
import re
from datetime import datetime, timedelta



# Import my files.
import snowflake_functions as sf  # Import the notebook as a module.
import transform_data as td 
import extract_data as ed 
import data_presentation as dp 
from skills_array import get_skills_array
skills_array = get_skills_array() # get full list of skills.

# %%
# upload latest function
importlib.reload(sf)
importlib.reload(ed)
importlib.reload(td)

# initialise URL list
full_URLs = []

# intialise tables that will later be loaded to snowflake
job_table = pd.DataFrame(columns=['JOB_ID', 'TITLE','COMPANY','LOCATION','EMPLOYMENT_TYPE','SALARY','PAY_PERIOD','POST_DATE'])
job_skills_table = pd.DataFrame(columns=["skill_id", "skill_name"])

# connection snowflake
engine = sf.connect_snowflake(password)
connection = engine.connect()

# get the job_id of the last entry in the jobs table
job_id = sf.last_job_id(connection) + 1

# get job URL links from the first 'max_pages' of data engineer SEEK website pages.
max_pages = 1
full_urls = ed.get_URLs(max_pages)
    
# go through all the URLs and extract relevant data.
for k, url in enumerate(full_urls):   
    
    # Scrape job URL.
    response = requests.get(url) 
    soup = BeautifulSoup(response.content, "html.parser") 
    
    # Extract job data and format it go into a table.
    job_props, req_skills = ed.get_job_data(soup, skills_array) # extract the information from job
    parsed_salary = td.parse_salary(job_props[4]) # clean up salary   
    job_table = td.update_job_table(job_props, parsed_salary, job_table, job_id + k) # put into data frame.


    # Extract the required skills for each job advertisment and record in a table.
    df_skill_ids = sf.get_skill_ids(req_skills, connection)
    job_skills_table = td.update_job_skills_table(job_props, parsed_salary, job_skills_table, df_skill_ids, job_id + k)
        

# upload tables to snowflake database.
job_table.to_sql('jobs', con=engine, if_exists='append', index=False)
job_skills_table.to_sql('job_skills', con=engine, if_exists='append', index=False)
print(f"\n\n{job_table.shape[0]} SEEK job advertisements added to database.")

# Remove duplicates.
sf.remove_duplicate_entries(connection, password)

# Close connection
connection.close()
# Out:
# Connected to Snowflake!
# Data Engineer *Mid-level* | FinXL IT Professional Services | Sydney NSW | Contract/Temp | None | None | 2025-02-19
# AWS Data Engineer | FinXL IT Professional Services | Sydney NSW | Contract/Temp | 140000 | daily | None
# Senior Data Engineer | Talenza | Sydney NSW | Contract/Temp | 900 | daily | 2025-03-01
# Junior Cloud Engineer | ASIC | Sydney NSW | Full time | None | None | 2025-02-28
# Senior Engineer - Data and Integration | Insignia Financial Ltd | Sydney NSW | Full time | None | None | None
# Cloud Data Engineer | Cuscal Limited (SR) | Sydney NSW | Full time | None | None | None
# Lead Data Engineer / Scientist - Up to $220K + Super + Shares | Private Advertiser | Sydney NSW | Full time | 220000 | annually | 2025-02-28
# Senior Data Engineer | u&u. Recruitment Partners | Sydney NSW | Contract/Temp | None | None | 2025-03-01
# Data Engineer | Talent Insights Group Pty Ltd | Sydney NSW | Contract/Temp | None | None | 2025-02-26
# 2026 Australian Government Graduate Program - Data Stream | Australian Bureau of Statistics | Sydney NSW | Full time | 63000 | annually | None
# Senior Data Engineer | Teachers Health Fund | Surry Hills, Sydney NSW | Full time | None | None | 2025-02-25
# Data Engineer | Cuscal Limited (SR) | Sydney NSW | Full time | None | None | 2025-02-22
# Machine Learning & Data Engineer | Fundo Loans | Sydney NSW | Full time | 140000 | annually | 2025-02-25
# Machine Learning & Data Engineer | Fundo Loans | Sydney NSW | Full time | 140000 | annually | 2025-02-25
# Data Engineer | Bluestone | Sydney NSW | Full time | None | None | 2025-02-22
# Data Analyst | Northbridge Recruitment | North Sydney, Sydney NSW | Contract/Temp | None | None | 2025-03-03
# Senior Data Engineer | Talenza | Sydney NSW | Full time | 160000 | annually | 2025-02-25
# Senior Data Modeller | Talenza | Sydney NSW | Full time | 1000 | daily | None
# Senior Engineer - Data and Integration | Insignia Financial Ltd | Sydney NSW | Full time | None | None | None
# Senior Data Engineer (GCP) | Talenza | Sydney NSW | Full time | 175000 | annually | 2025-03-01
# Senior Data Engineer | Talenza | Sydney NSW | Full time | 175000 | annually | 2025-02-25
# Data Engineer | Tranzformd | Sydney NSW | Full time | None | None | 2025-02-25
#
#
# 22 SEEK job advertisements added to database.
# 20 duplicate job advertisements removed.

# %%
# upload latest function
importlib.reload(sf)
importlib.reload(ed)
importlib.reload(td)
importlib.reload(dp)

# salary range to consider
min_salary = 60e3
max_salary = 220e3

# connection snowflake
engine = sf.connect_snowflake(password)
connection = engine.connect()

# present data
hist_file_name = 'skills_hist'
salary_file_name = 'salary_hist'
dp.hist_popular_skills(connection, hist_file_name)
dp.hist_annual_salaries(connection, min_salary, max_salary, salary_file_name)

# Close connection
connection.close()
# Out:
# Connected to Snowflake!
