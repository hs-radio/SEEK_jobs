# %%
# update skills list.
def get_skills_array():
    skills_array = [
        # 🔹 General Data Engineering Expressions
        "Data Engineering", "Data Engineer", "Data Pipelines", "Big Data", 
        "Data Warehouse", "ETL", "ELT", "Data Modeling", "Data Architecture", 
        "Streaming Data", "Batch Processing", "Real-Time Processing", "Data Lake",
        "Cloud Data", "Data Governance", "Data Security", "DataOps",
        "CI/CD", "Version Control", "Git", "GitHub", "GitLab", "Bitbucket",
        "Infrastructure as Code (IaC)", "DevOps", "Monitoring and Logging", 
        "Data Quality", "Data Integrity", "Data Compliance", "ETL Testing",
        
        # 🔹 Programming Languages
        "Python", "SQL", "Java", "Scala", "C++", "R", "Go", "Rust", "Bash", "Shell Scripting",
        
        # 🔹 Databases & Storage
        "PostgreSQL", "MySQL", "MSSQL", "Oracle", "DB2", "Teradata", "MongoDB", 
        "Cassandra", "DynamoDB", "Snowflake", "BigQuery", "Amazon Redshift", 
        "Vertica", "CouchDB", "Elasticsearch", "Neo4j", "InfluxDB", "ClickHouse", 
        "Memcached", "Redis",

        # 🔹 Cloud Platforms
        "AWS", "Azure", "GCP", "IBM Cloud", "Oracle Cloud", "Alibaba Cloud",
        
        # 🔹 AWS Services
        "AWS Lambda", "AWS Glue", "AWS S3", "AWS Athena", "AWS EMR", "AWS Redshift",
        "AWS Step Functions", "AWS RDS", "AWS DynamoDB", "AWS Kinesis", "AWS SQS",
        "AWS SNS", "AWS IAM", "AWS API Gateway", "AWS CloudFormation", "AWS CloudWatch",
        "AWS CodePipeline", "AWS ECS", "AWS EKS", "AWS Fargate",

        # 🔹 Azure Services
        "Azure Data Factory", "Azure Synapse", "Azure Blob Storage", "Azure SQL Database",
        "Azure Cosmos DB", "Azure Event Hubs", "Azure Functions", "Azure Databricks",
        "Azure DevOps", "Azure Data Lake Storage", "Azure Monitor",

        # 🔹 GCP Services
        "BigQuery", "Cloud Storage", "Cloud Dataflow", "Cloud Pub/Sub", "Cloud Composer",
        "Cloud Functions", "Google Kubernetes Engine (GKE)", "Cloud Spanner",

        # 🔹 Data Processing & Pipelines
        "Apache Hadoop", "Apache Spark", "Apache Flink", "Apache Beam", "Apache NiFi",
        "Kafka Streams", "Kubernetes", "Docker", "Airflow", "Luigi", "Prefect",
        "TensorFlow Extended (TFX)", "Great Expectations", "Data Orchestration",
        
        # 🔹 Data Formats & Serialization
        "Parquet", "Avro", "ORC", "JSON", "XML", "CSV", "YAML", "Protocol Buffers (Protobuf)", "MessagePack",

        # 🔹 Business Intelligence & Visualization
        "Tableau", "Power BI", "Looker", "Qlik Sense", "Google Data Studio", "Mode Analytics",
        "Metabase", "Domo", "MicroStrategy", "SAP BusinessObjects",

        # 🔹 DevOps, CI/CD, & Infrastructure
        "Terraform", "Ansible", "Pulumi", "CloudFormation", "Docker", "Kubernetes",
        "Jenkins", "GitHub Actions", "CircleCI", "TravisCI", "ArgoCD", "Spinnaker",

        # 🔹 Streaming & Messaging Systems
        "Kafka", "Pulsar", "RabbitMQ", "ActiveMQ", "ZeroMQ", "NATS", "Azure Event Hub",
        "Google Pub/Sub", "AWS Kinesis",

        # 🔹 APIs & Data Integration
        "REST APIs", "GraphQL", "gRPC", "ODBC", "JDBC", "WebSockets",
        "iPaaS", "Zapier", "MuleSoft", "Talend", "Boomi", "Fivetran", "StitchData",

        # 🔹 Security & Compliance
        "IAM", "OAuth", "JWT", "SSL/TLS", "SOC 2", "GDPR", "HIPAA", "PCI DSS",
        "Data Masking", "Data Lineage", "Data Encryption",

        # 🔹 Log Processing & Monitoring
        "Splunk", "ELK Stack (Elasticsearch, Logstash, Kibana)", "Grafana", "Prometheus",
        "CloudWatch", "Datadog", "New Relic", "OpenTelemetry",

        # 🔹 Other Tools & Frameworks
        "DAX", "Power Query", "CRM", "STIBO", "Salesforce", "Genesys Cloud",
        "Microsoft Dynamics 365", "HRIS", "ATS", "CDMP", "Power Automate",
        
        # 🔹 Machine Learning & AI (Optional but useful for data engineers)
        "TensorFlow", "PyTorch", "MLflow", "Kubeflow", "Feature Store",
        "DataRobot", "Hugging Face Transformers"
    ]
    return skills_array



# skills_array = get_skills_array()
# df = pd.DataFrame({
#     'skill_id': range(1, len(skills_array) + 1),  # Generate skill_id starting from 1
#     'skill_name': skills_array
# })
# connection = engine.connect()


# df.to_sql("skills_list", con = engine, if_exists='replace', index=False)
