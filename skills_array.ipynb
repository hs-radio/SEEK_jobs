# %%
def get_skills_array():
    skills_array = [
        # Data Visualization & BI
        "Power BI", "Tableau", "Looker", "QlikSense", "Google Data Studio", "DAX", "Power Query",
        
        # Databases & Query Languages
        "SQL", "MSSQL", "PostgreSQL", "MySQL", "Oracle", "SQLite", "MongoDB", "Cassandra", 
        "Redis", "Neo4j", "BigQuery", "Snowflake", "Teradata", "Presto", "Vertica", "ODBC", 
        
        # Data Processing & ETL
        "ETL", "ELT", "Apache Nifi", "Apache Airflow", "Azure Data Factory", "AWS Glue", 
        "Data Warehousing", "Data Pipelines", "Informatica", "SSIS", "Pentaho", "Talend", 
        "dbt (data build tool)", "Matillion", 
        
        # Cloud Platforms
        "AWS", "Azure", "GCP", "Google Cloud Functions", "Lambda", "AWS S3", "AWS Redshift", 
        "Azure Synapse", "Google Cloud Storage", "CloudFormation", "Terraform", 
        
        # Big Data & Streaming
        "Hadoop", "Spark", "Kafka", "Apache Flink", "Apache Beam", "Hive", "Impala", "Kinesis", 
        "AWS SQS", "SNS", "Google Pub/Sub", 
        
        # Programming Languages
        "Python", "Java", "Scala", "R", "Go", "Julia", "C++", "C#", "Bash", "Shell Scripting", 
        
        # APIs & Integration
        "API Development", "REST API", "GraphQL", "gRPC", "Postman", "Swagger", "FastAPI", 
        "Flask", "Django", "Express.js", "Node.js", "iPaaS", "Zapier", "Power Automate", 
        
        # DevOps, CI/CD & Infrastructure
        "CI/CD", "GitHub", "GitLab", "Bitbucket", "Jenkins", "Docker", "Kubernetes", "Ansible", 
        "Helm", "Grafana", "Prometheus", "New Relic", 
        
        # Data Formats & Serialization
        "JSON", "XML", "Parquet", "Avro", "ORC", "CSV", "YAML", 
        
        # Machine Learning & AI (for Data Engineers with ML focus)
        "TensorFlow", "PyTorch", "Scikit-learn", "MLflow", "Kubeflow", "AutoML", 
        
        # Other Tools & General Expressions
        "PowerPoint", "Excel", "Microsoft Word", "Microsoft Dynamics 365", "STIBO", 
        "Salesforce", "Genesys Cloud", "CDMP", "CRM", "ATS", "HRIS", "Data Governance", 
        "Data Security", "Data Quality", "Data Modeling", "Data Lake", "Data Fabric", 
        "Metadata Management", "Master Data Management (MDM)", "DataOps", "Observability", 
        "Data Mesh", "Data Contracts"
    ]
    return skills_array
